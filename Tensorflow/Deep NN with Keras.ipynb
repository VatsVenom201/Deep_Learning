# %% [markdown]
# # Price Prediction with Deep Neural Network

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('ford.csv')

# %%
df.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0

# %% [markdown]
# ## Data Preprocessing and Cleaning

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# %%
def auto_label_encode(df):
    df = df.copy()
    encoders = {}

    for col in df.select_dtypes(include='object'):
      
        df[col] = le.fit_transform(df[col])
        encoders[col] = le

    return df, encoders

# %%
enc_df , encoders= auto_label_encode(df)

# %%
enc_df
# Out:
#        model  year  price  transmission  mileage  fuelType  tax   mpg  \
# 0          5  2017  12000             0    15944         4  150  57.7
# 1          6  2018  14000             1     9083         4  150  57.7
# 2          6  2017  13000             1    12456         4  150  57.7
# 3          5  2019  17500             1    10460         4  145  40.3
# 4          5  2019  16500             0     1482         4  145  48.7
# ...      ...   ...    ...           ...      ...       ...  ...   ...
# 17961      0  2017   8999             1    16700         4  150  47.1
# 17962      0  2014   7499             1    40700         4   30  57.7
# 17963      6  2015   9999             1     7010         0   20  67.3
# 17964     11  2018   8299             1     5007         4  145  57.7
# 17965     23  2015   8299             1     5007         4   22  57.7
#
#        engineSize
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.5
# 4             1.0
# ...           ...
# 17961         1.4
# 17962         1.0
# 17963         1.6
# 17964         1.2
# 17965         1.0
#
# [17966 rows x 9 columns]

# %%
train, test = train_test_split(enc_df, test_size=0.2)

# %%
X_train = train.drop(columns=['price'])
y_train = train['price']

X_test = test.drop(columns=['price'])
y_test = test['price']

# %%
X_train
# Out:
#        model  year  transmission  mileage  fuelType  tax   mpg  engineSize
# 1543       1  2014             1    39549         0   30  61.4         1.6
# 16571      2  2016             0     7600         4  160  44.8         1.5
# 5902       5  2017             1    22025         4  145  65.7         1.0
# 2072       5  2014             1    55259         4   30  54.3         1.2
# 10991     14  2019             0     4665         2  135  47.1         2.0
# ...      ...   ...           ...      ...       ...  ...   ...         ...
# 15455      2  2018             0     2261         4  145  45.6         1.0
# 9088       6  2018             1     8201         4  150  58.9         1.0
# 1440       6  2016             1    26000         0   20  67.3         2.0
# 454        0  2015             1     9708         0   20  70.6         1.6
# 13955      2  2015             1    11696         0   30  61.4         1.5
#
# [14372 rows x 8 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
num_vars =['year','mileage','tax','mpg']
num_vars
# Out:
# ['year', 'mileage', 'tax', 'mpg']

# %%
scaler = MinMaxScaler()

scaler.fit(X_train[num_vars])

X_train[num_vars] = scaler.transform(X_train[num_vars])
X_test[num_vars] = scaler.transform(X_test[num_vars])

# %%
X_train
# Out:
#        model      year  transmission   mileage  fuelType       tax       mpg  \
# 1543       1  0.233333             1  0.222626         0  0.052632  0.224309
# 16571      2  0.266667             0  0.042777         4  0.280702  0.132597
# 5902       5  0.283333             1  0.123979         4  0.254386  0.248066
# 2072       5  0.233333             1  0.311062         4  0.052632  0.185083
# 10991     14  0.316667             0  0.026255         2  0.236842  0.145304
# ...      ...       ...           ...       ...       ...       ...       ...
# 15455      2  0.300000             0  0.012722         4  0.254386  0.137017
# 9088       6  0.300000             1  0.046160         4  0.263158  0.210497
# 1440       6  0.266667             1  0.146355         0  0.035088  0.256906
# 454        0  0.250000             1  0.054643         0  0.035088  0.275138
# 13955      2  0.250000             1  0.065834         0  0.052632  0.224309
#
#        engineSize
# 1543          1.6
# 16571         1.5
# 5902          1.0
# 2072          1.2
# 10991         2.0
# ...           ...
# 15455         1.0
# 9088          1.0
# 1440          2.0
# 454           1.6
# 13955         1.5
#
# [14372 rows x 8 columns]

# %%
y_train
# Out:
# 1543      7591
# 16571    10995
# 5902      9991
# 2072      5495
# 10991    22899
#          ...
# 15455    15800
# 9088     14995
# 1440     14795
# 454       7698
# 13955     9000
# Name: price, Length: 14372, dtype: int64

# %% [markdown]
# ## Input featueres...

# %%
X_train.shape
# Out:
# (14372, 8)

# %% [markdown]
# ## Neural network

# %%
import  tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ## Using sequential api for model building

# %%
model = keras.Sequential([
    layers.Input(shape=(8,)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(10,activation='relu'),
    layers.Dense(1)  # we dont need activation for a regression problem's output layer 
])

# %% [markdown]
# ## Neural net looks like...

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 128)                 │           1,152 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │             650 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              11 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 10,069 (39.33 KB)
#  Trainable params: 10,069 (39.33 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Compiling - stating optimizer and loss func to be used in backpropogation

# %%
model.compile(
    optimizer='adam',
    loss='mse',       # loss func used for updating params in backprop
    metrics=['mae']   # loss func it calc. per each epoch for logging 
)

# %% [markdown]
# ## fitting model with training data

# %%
model.fit(X_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 956us/step - loss: 85909632.0000 - mae: 7401.6445
# Epoch 2/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - loss: 22826978.0000 - mae: 3523.9177
# Epoch 3/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - loss: 19793332.0000 - mae: 3300.1907
# Epoch 4/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 16642895.0000 - mae: 3046.7571
# Epoch 5/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - loss: 13938498.0000 - mae: 2815.8818
# Epoch 6/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 11738559.0000 - mae: 2577.6328
# Epoch 7/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - loss: 9991522.0000 - mae: 2362.3181
# Epoch 8/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - loss: 8897765.0000 - mae: 2238.0383
# Epoch 9/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - loss: 8313068.5000 - mae: 2176.5593
# Epoch 10/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - loss: 7984640.0000 - mae: 2139.6587
# Epoch 11/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - loss: 7717989.5000 - mae: 2101.7329
# Epoch 12/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - loss: 7513376.0000 - mae: 2068.0850
# Epoch 13/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - loss: 7348390.5000 - mae: 2045.2573
# Epoch 14/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - loss: 7204768.0000 - mae: 2024.3632
# Epoch 15/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - loss: 7053397.0000 - mae: 1995.4293
# Epoch 16/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 6906095.0000 - mae: 1972.1991
# Epoch 17/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 888us/step - loss: 6774071.0000 - mae: 1952.1556
# Epoch 18/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6630224.5000 - mae: 1929.7957
# Epoch 19/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 874us/step - loss: 6505165.5000 - mae: 1904.6163
# Epoch 20/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 6383511.0000 - mae: 1886.3711
# Epoch 21/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - loss: 6252092.0000 - mae: 1862.4773
# Epoch 22/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6114993.0000 - mae: 1840.4609
# Epoch 23/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 6019880.5000 - mae: 1822.9835
# Epoch 24/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 5890830.5000 - mae: 1801.0636
# Epoch 25/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5775544.5000 - mae: 1778.8624
# Epoch 26/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 5701040.5000 - mae: 1765.4437
# Epoch 27/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 5595685.5000 - mae: 1742.9486
# Epoch 28/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5482654.5000 - mae: 1723.0938
# Epoch 29/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5357789.5000 - mae: 1702.4297
# Epoch 30/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 5269810.5000 - mae: 1683.2803
# Epoch 31/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 5177641.5000 - mae: 1665.9413
# Epoch 32/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 5058477.0000 - mae: 1643.3899
# Epoch 33/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - loss: 4950823.0000 - mae: 1619.3228
# Epoch 34/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - loss: 4882565.0000 - mae: 1606.6658
# Epoch 35/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - loss: 4787668.5000 - mae: 1585.7449
# Epoch 36/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4710232.0000 - mae: 1571.6541
# Epoch 37/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4648721.5000 - mae: 1556.2694
# Epoch 38/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4548477.5000 - mae: 1532.8148
# Epoch 39/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4503234.0000 - mae: 1524.8302
# Epoch 40/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - loss: 4441197.0000 - mae: 1509.8639
# Epoch 41/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - loss: 4386640.5000 - mae: 1494.4272
# Epoch 42/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - loss: 4335601.0000 - mae: 1480.3174
# Epoch 43/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 899us/step - loss: 4299550.0000 - mae: 1471.4694
# Epoch 44/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - loss: 4246554.0000 - mae: 1459.9600
# Epoch 45/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4200709.0000 - mae: 1447.6351
# Epoch 46/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4170323.2500 - mae: 1441.3282
# Epoch 47/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4106730.2500 - mae: 1426.4678
# Epoch 48/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 4067043.0000 - mae: 1415.7299
# Epoch 49/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4041279.2500 - mae: 1406.8827
# Epoch 50/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - loss: 3993872.0000 - mae: 1397.1167
# Epoch 51/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3960174.5000 - mae: 1387.2548
# Epoch 52/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 3919984.2500 - mae: 1376.8356
# Epoch 53/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step - loss: 3860543.5000 - mae: 1366.2650
# Epoch 54/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - loss: 3833573.2500 - mae: 1356.6809
# Epoch 55/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3839345.2500 - mae: 1356.4929
# Epoch 56/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - loss: 3776347.7500 - mae: 1344.8416
# Epoch 57/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 3778083.7500 - mae: 1338.5967
# Epoch 58/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - loss: 3735889.7500 - mae: 1332.1449
# Epoch 59/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3708142.5000 - mae: 1322.1786
# Epoch 60/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3680953.7500 - mae: 1315.4966
# Epoch 61/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - loss: 3678135.5000 - mae: 1313.4974
# Epoch 62/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 938us/step - loss: 3641421.2500 - mae: 1311.6926
# Epoch 63/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3645042.7500 - mae: 1308.3807
# Epoch 64/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3625779.7500 - mae: 1303.8844
# Epoch 65/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 3588208.0000 - mae: 1294.8369
# Epoch 66/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3570846.7500 - mae: 1294.7412
# Epoch 67/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3553517.5000 - mae: 1291.2729
# Epoch 68/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3539083.7500 - mae: 1283.7638
# Epoch 69/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - loss: 3530200.0000 - mae: 1284.2765
# Epoch 70/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - loss: 3511198.7500 - mae: 1279.0669
# Epoch 71/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - loss: 3485368.7500 - mae: 1272.4445
# Epoch 72/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 3478946.0000 - mae: 1273.1216
# Epoch 73/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - loss: 3463049.2500 - mae: 1266.3829
# Epoch 74/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - loss: 3466534.5000 - mae: 1267.1208
# Epoch 75/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3440284.0000 - mae: 1261.3854
# Epoch 76/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3423588.7500 - mae: 1261.6083
# Epoch 77/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - loss: 3392025.5000 - mae: 1252.0376
# Epoch 78/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - loss: 3392254.7500 - mae: 1253.8757
# Epoch 79/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 3375291.5000 - mae: 1250.2418
# Epoch 80/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - loss: 3379965.5000 - mae: 1252.5724
# Epoch 81/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - loss: 3370288.0000 - mae: 1246.8336
# Epoch 82/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - loss: 3335925.2500 - mae: 1243.5573
# Epoch 83/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - loss: 3318134.0000 - mae: 1239.8286
# Epoch 84/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3323737.7500 - mae: 1238.1101
# Epoch 85/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 3309086.0000 - mae: 1235.3896
# Epoch 86/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 3280887.7500 - mae: 1232.7345
# Epoch 87/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 3273831.5000 - mae: 1230.0944
# Epoch 88/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3271828.2500 - mae: 1229.3535
# Epoch 89/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 952us/step - loss: 3279203.5000 - mae: 1234.1537
# Epoch 90/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3213919.2500 - mae: 1218.9346
# Epoch 91/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - loss: 3237165.7500 - mae: 1225.4905
# Epoch 92/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3198625.0000 - mae: 1217.0044
# Epoch 93/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - loss: 3199198.5000 - mae: 1216.4142
# Epoch 94/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 934us/step - loss: 3184773.0000 - mae: 1211.4774
# Epoch 95/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 3179534.2500 - mae: 1212.7627
# Epoch 96/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3161440.5000 - mae: 1209.5156
# Epoch 97/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 909us/step - loss: 3131317.2500 - mae: 1203.1609
# Epoch 98/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - loss: 3134251.0000 - mae: 1203.4348
# Epoch 99/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 3111995.7500 - mae: 1202.2676
# Epoch 100/100
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 3118231.2500 - mae: 1203.2422

# %%
mse , mae = model.evaluate(x=X_test,y=y_test)
print(mae)
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3023012.7500 - mae: 1177.3622
# 1177.3621826171875

# %%
y_pred = model.predict(X_test)
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step

# %%
y_pred = y_pred.flatten()

# %%
comparison = pd.DataFrame({
    'Actual': y_test.values,
    'Predicted': y_pred
})

comparison.head(20)
# Out:
#     Actual     Predicted
# 0    16499  16075.279297
# 1     6475   7380.877930
# 2    18000  14909.451172
# 3     9600   8953.931641
# 4    11998  11146.221680
# 5    18975  16857.328125
# 6     6200   6379.864258
# 7    10995   9132.835938
# 8    16495  15562.777344
# 9     7890   8811.210938
# 10   17991  17853.167969
# 11   14800  14036.880859
# 12   18998  17095.771484
# 13   15299  13431.645508
# 14   18125  20668.480469
# 15   20995  19815.804688
# 16    9998  12267.454102
# 17    9350   8923.980469
# 18   21290  20845.636719
# 19   13495   9323.491211

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import r2_score
r2= r2_score(y_pred,y_test.values)
print(f'Mean Squared Error : {mse}\n')
print(f'Mean Absolute Error : {mae}\n')
print(f'R2 Score : {r2}\n')
# Out:
# Mean Squared Error : 3023012.75
#
# Mean Absolute Error : 1177.3621826171875
#
# R2 Score : 0.8279984593391418
